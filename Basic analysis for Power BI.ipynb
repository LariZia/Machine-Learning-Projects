# %%
import pandas as pd

# %%
df = pd.read_excel('SuperStoreUS-2015.xlsx', sheet_name = None)

# %%
df
# Out:
# {'Orders':       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
#  0      20847           High      0.01        2.84           0.93            3
#  1      20228  Not Specified      0.02      500.98          26.00            5
#  2      21776       Critical      0.06        9.48           7.29           11
#  3      24844         Medium      0.09       78.69          19.99           14
#  4      24846         Medium      0.08        3.28           2.31           14
#  ...      ...            ...       ...         ...            ...          ...
#  1947   19842           High      0.01       10.90           7.46         3397
#  1948   19843           High      0.10        7.99           5.03         3397
#  1949   26208  Not Specified      0.08       11.97           5.81         3399
#  1950   24911         Medium      0.10        9.38           4.93         3400
#  1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
list(df.keys())
# Out:
# ['Orders', 'Returns', 'Users']

# %%
d1 = df["Orders"]
d1.head(20)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    20847           High      0.01        2.84           0.93            3
# 1    20228  Not Specified      0.02      500.98          26.00            5
# 2    21776       Critical      0.06        9.48           7.29           11
# 3    24844         Medium      0.09       78.69          19.99           14
# 4    24846         Medium      0.08        3.28           2.31           14
# 5    24847         Medium      0.05        3.28           4.20           14
# 6    24848         Medium      0.05        3.58           1.63           14
# 7    18181       Critical      0.00        4.42           4.99           15
# 8    20925         Medium      0.01       35.94           6.66           15
# 9    26267           High      0.04        2.98           1.58           16
# 10   26268           High      0.05      115.99           2.50           16
# ...

# %%
print(d1.shape)
d1.info()
# Out:
# (1952, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
# ...

# %%
d1[d1["Region"]=="Central"]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# 5      24847         Medium      0.05        3.28           4.20           14
# 6      24848         Medium      0.05        3.58           1.63           14
# 31     22890           High      0.02        5.98           5.15           62
# ...      ...            ...       ...         ...            ...          ...
# 1922   23887         Medium      0.03        4.98           4.95         3361
# 1946   20624            Low      0.00     1270.99          19.99         3397
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
#
# ...

# %%
d2 = df["Returns"]
d2.head(20)
# Out:
#     Order ID    Status
# 0         65  Returned
# 1        612  Returned
# 2        614  Returned
# 3        678  Returned
# 4        710  Returned
# 5        740  Returned
# 6        775  Returned
# 7        833  Returned
# 8        902  Returned
# 9       3300  Returned
# 10      3456  Returned
# 11      3525  Returned
# 12      3589  Returned
# 13      3687  Returned
# 14      3777  Returned
# 15      3783  Returned
# 16      4006  Returned
# 17      4037  Returned
# 18      4230  Returned
# 19      4261  Returned

# %%
print(d2.shape)
d2.info()
# Out:
# (1634, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1634 entries, 0 to 1633
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order ID  1634 non-null   int64
#  1   Status    1634 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 25.7+ KB

# %%
d2["Status"].unique()
# Out:
# array(['Returned'], dtype=object)

# %%
d3 = df["Users"]
d3.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
print(d3.shape)
d3.info()
# Out:
# (4, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Region   4 non-null      object
#  1   Manager  4 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
result = pd.merge(d1, d3, on=["Region", "Region"])

# %%
result
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      23890           High      0.05       26.48           6.93           18
# 3      24063  Not Specified      0.07       12.99           9.44           19
# 4      20631           High      0.06       55.48          14.30           24
# ...      ...            ...       ...         ...            ...          ...
# 1947   23181       Critical      0.03      315.98          19.99         3380
# 1948   23182       Critical      0.09      276.20          24.49         3380
# 1949   23183       Critical      0.03       63.94          14.48         3380
# 1950   24161  Not Specified      0.05       11.97           5.81         3381
# 1951   25841         Medium      0.02       28.53           1.49         3381
#
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1952 entries, 0 to 1951
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
#result.to_excel("dump.xlsx")

# %%
pd.read_excel("dump.xlsx")
# Out:
#       Unnamed: 0  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0              0   20847           High      0.01        2.84           0.93
# 1              1   20228  Not Specified      0.02      500.98          26.00
# 2              2   23890           High      0.05       26.48           6.93
# 3              3   24063  Not Specified      0.07       12.99           9.44
# 4              4   20631           High      0.06       55.48          14.30
# ...          ...     ...            ...       ...         ...            ...
# 1947        1947   23181       Critical      0.03      315.98          19.99
# 1948        1948   23182       Critical      0.09      276.20          24.49
# 1949        1949   23183       Critical      0.03       63.94          14.48
# 1950        1950   24161  Not Specified      0.05       11.97           5.81
# 1951        1951   25841         Medium      0.02       28.53           1.49
#
# ...

# %%
result.corr()
# Out:
#                         Row ID  Discount  Unit Price  Shipping Cost  \
# Row ID                1.000000  0.018215   -0.004427      -0.016027
# Discount              0.018215  1.000000   -0.008202       0.039908
# Unit Price           -0.004427 -0.008202    1.000000       0.198793
# Shipping Cost        -0.016027  0.039908    0.198793       1.000000
# Customer ID           0.064071  0.014534   -0.008717      -0.016805
# Product Base Margin   0.000137  0.018656    0.029086       0.361952
# Postal Code           0.033578 -0.025247    0.016086      -0.033903
# Profit               -0.038468 -0.061821   -0.182067       0.002177
# Quantity ordered new -0.568939 -0.009398   -0.072472      -0.009735
# Sales                -0.258827 -0.030287    0.443509       0.322133
# Order ID              0.918497  0.016719    0.003292      -0.014691
#
#                       Customer ID  Product Base Margin  Postal Code    Profit  \
# ...

# %%
result.cov()
# Out:
#                             Row ID   Discount     Unit Price  Shipping Cost  \
# Row ID                3.549295e+07   3.405028  -10377.341902   -1662.840953
# Discount              3.405028e+00   0.000985      -0.101272       0.021807
# Unit Price           -1.037734e+04  -0.101272  154827.534308    1362.195244
# Shipping Cost        -1.662841e+03   0.021807    1362.195244     303.269387
# Customer ID           3.783064e+05   0.451970   -3399.538743    -290.039124
# Product Base Margin   1.117946e-01   0.000080       1.573953       0.857693
# Postal Code           5.873912e+06 -23.261364  185857.674208  -17335.898146
# Profit               -2.615198e+05  -2.213585  -81749.374525      43.269440
# Quantity ordered new -4.701779e+04  -0.004091    -395.566035      -2.351589
# Sales                -3.947334e+06  -2.432777  446734.613007   14360.599351
# Order ID              1.042001e+08   9.990091   24669.582345   -4871.782078
#
# ...

# %%
fdf = result.copy()

# %%
fdf.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID', 'Manager'],
#       dtype='object')

# %%
len(fdf['Sales'].unique())
# Out:
# 1922

# %%
fdf= fdf.drop(["Row ID", "Customer ID" , "Postal Code", "Order ID", "Order ID","Customer ID", \
          'Product Name', "Customer Name", 'Postal Code', "Country"], axis =1
        )

# %%
fdf.columns
# Out:
# Index(['Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Ship Mode', 'Customer Segment', 'Product Category',
#        'Product Sub-Category', 'Product Container', 'Product Base Margin',
#        'Region', 'State or Province', 'City', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Manager'],
#       dtype='object')

# %%
fdf.head(10)
# Out:
#   Order Priority  Discount  Unit Price  Shipping Cost       Ship Mode  \
# 0           High      0.01        2.84           0.93     Express Air
# 1  Not Specified      0.02      500.98          26.00  Delivery Truck
# 2           High      0.05       26.48           6.93     Regular Air
# 3  Not Specified      0.07       12.99           9.44     Regular Air
# 4           High      0.06       55.48          14.30     Regular Air
# 5           High      0.02        1.68           1.57     Regular Air
# 6  Not Specified      0.04        4.14           6.60     Regular Air
# 7           High      0.08       34.99           7.73     Regular Air
# 8           High      0.01       17.98           8.51     Regular Air
# 9         Medium      0.09      125.99           7.69     Express Air
#
#   Customer Segment Product Category          Product Sub-Category  \
# 0        Corporate  Office Supplies           Pens & Art Supplies
# ...

# %%
fdf.shape
# Out:
# (1952, 19)

# %%
len(fdf["City"].unique())
# Out:
# 869

# %%
1952-869
# Out:
# 1083

# %%
fdf[["Unit Price", "Shipping Cost", "Discount","Profit", "Quantity ordered new", "Sales", "Product Base Margin" ]]
# Out:
#       Unit Price  Shipping Cost  Discount     Profit  Quantity ordered new  \
# 0           2.84           0.93      0.01     4.5600                     4
# 1         500.98          26.00      0.02  4390.3665                    12
# 2          26.48           6.93      0.05   314.4813                    17
# 3          12.99           9.44      0.07  -114.6399                    18
# 4          55.48          14.30      0.06   -28.2968                     1
# ...          ...            ...       ...        ...                   ...
# 1947      315.98          19.99      0.03    -4.4800                    18
# 1948      276.20          24.49      0.09  3193.2840                    11
# 1949       63.94          14.48      0.03    43.6917                     8
# 1950       11.97           5.81      0.05   349.0593                     2
# 1951       28.53           1.49      0.02     1.9920                    18
#
#         Sales  Product Base Margin
# ...

# %%
(455.77 - 314.4813)/26.48
# Out:
# 5.335675981873112

# %%
13.01- ((2.84*4)-(2.84*0.01))
# Out:
# 1.6784

# %%
# cp+pm*x = x
# 26.48+ 0.49*x = x
# 26.48 = 0.51x
455.77 + 314.4813
# Out:
# 770.2512999999999

# %%
26.48/.51
# Out:
# 51.92156862745098

# %%
(51.921*17)- (51.921*0.05)
# Out:
# 880.06095

# %%
# Product margin= (selling price – cost of product) / selling price
# pm = (x-cp)/x
# pm*x =x-cp
# cp+pm*x = x

# %%
x = 1
x += 2
x
# Out:
# 3

# %%
city = fdf["City"]

# %%
nd= {}

for i in city:
    if i in nd:
        nd[i] += 1
    else:
        nd[i] = 1

# %%
x = []
for i in nd:
    if nd.get(i) > 5:
        x.append([i, nd.get(i)])

# %%
def takeSecond(elem):
    return elem[1]
x.sort(reverse = True, key = takeSecond )
x
# Out:
# [['New York City', 47],
#  ['Los Angeles', 44],
#  ['Seattle', 21],
#  ['Boston', 19],
#  ['Washington', 15],
#  ['Philadelphia', 12],
#  ['Charlotte', 12],
#  ['Chicago', 11],
#  ['Sanford', 10],
#  ['Miami', 10],
#  ['Atlanta', 9],
#  ['San Diego', 8],
#  ['Columbus', 8],
#  ['Prior Lake', 8],
#  ['Hilton Head Island', 8],
#  ['Twentynine Palms', 7],
#  ['Auburn', 7],
#  ['Newton', 7],
#  ['Norfolk', 7],
#  ['Greenville', 7],
#  ['Redmond', 6],
#  ['Aurora', 6],
#  ['Burlington', 6],
#  ['Troy', 6],
#  ['Detroit', 6],
#  ['Naperville', 6]]

# %% [markdown]
# ## TOP 4 CITIES THAT PURCHASES

# %%
top4 = x[0:4]

# %% [markdown]
# # PURCAHSES WITH RESPECT TO REGION

# %%
pd.get_dummies(data = fdf, columns = ["Region"])
# Out:
#      Order Priority  Discount  Unit Price  Shipping Cost       Ship Mode  \
# 0              High      0.01        2.84           0.93     Express Air
# 1     Not Specified      0.02      500.98          26.00  Delivery Truck
# 2              High      0.05       26.48           6.93     Regular Air
# 3     Not Specified      0.07       12.99           9.44     Regular Air
# 4              High      0.06       55.48          14.30     Regular Air
# ...             ...       ...         ...            ...             ...
# 1947       Critical      0.03      315.98          19.99     Regular Air
# 1948       Critical      0.09      276.20          24.49     Regular Air
# 1949       Critical      0.03       63.94          14.48     Regular Air
# 1950  Not Specified      0.05       11.97           5.81     Regular Air
# 1951         Medium      0.02       28.53           1.49     Regular Air
#
#      Product Category            Product Sub-Category Product Container  \
# ...

# %%
# Out:
#      Order Priority  Discount  Unit Price  Shipping Cost       Ship Mode  \
# 0              High      0.01        2.84           0.93     Express Air
# 1     Not Specified      0.02      500.98          26.00  Delivery Truck
# 2              High      0.05       26.48           6.93     Regular Air
# 3     Not Specified      0.07       12.99           9.44     Regular Air
# 4              High      0.06       55.48          14.30     Regular Air
# ...             ...       ...         ...            ...             ...
# 1947       Critical      0.03      315.98          19.99     Regular Air
# 1948       Critical      0.09      276.20          24.49     Regular Air
# 1949       Critical      0.03       63.94          14.48     Regular Air
# 1950  Not Specified      0.05       11.97           5.81     Regular Air
# 1951         Medium      0.02       28.53           1.49     Regular Air
#
#      Customer Segment Product Category            Product Sub-Category  \
# ...

# %% [markdown]
# # with respect to product category

# %%
fdf["Product Category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
#pd.get_dummies()
